# %%
import pandas as pd

# %%
df_wordl = pd.read_csv("files/world-data-2023_part1.csv", index_col=0)

df_wordl
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %% [markdown]
# ** EJERCICIOS EXPLORACION **
# 1. Muestra las primeras 5 filas del conjunto de datos.
#
# 2. Muestra las últimas 5 filas del conjunto de datos.
#
# 3. Muestra una muestra aleatoria de 5 filas del conjunto de datos.
#
# 4. Muestra el nombre de todas las columnas en el conjunto de datos.
#
# 5. Muestra los valores únicos en la columna "Abbreviation".

# %%
#1. Muestra las primeras 5 filas del conjunto de datos.
df_wordl.head(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
#1.1 Muestra las primeras 5 columnas
df_wordl.iloc[:, :5]
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2)
# 0          652,230
# 1           28,748
# 2        2,381,741
# 3              468
# 4        1,246,700
# ..             ...
# 190        912,050
# 191        331,210
# 192        527,968
# 193        752,618
# 194        390,757
#
# [195 rows x 5 columns]

# %%
#2. Muestra las últimas 5 filas del conjunto de datos.
df_wordl.tail(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %%
#Muestra una muestra aleatoria de 5 filas del conjunto de datos.
df_wordl.sample(5)
# Out:
#              Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 128  North Macedonia               83          NaN                   NaN
# 192            Yemen               56           YE                44.60%
# 68         Guatemala              167           GT                36.00%
# 138      Philippines              368           PH                41.70%
# 176            Tonga              147           TO                45.80%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 128         25,713               NaN         NaN         389.0
# 192        527,968            40,000       30.45         967.0
# 68         108,889            43,000       24.56         502.0
# 138        300,000           153,000       20.55          63.0
# 176            747               NaN       24.30         676.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 128             Skopje           NaN     NaN            NaN           MKD
# 192              Sanaa        10,609  157.58          8.10%           YER
# 68      Guatemala City        16,777  142.92          3.70%           GTQ
# 138             Manila       122,287  129.61          2.50%           PHP
# 176           Nuku����           128  121.09          7.40%           TOP
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 128             NaN               NaN            NaN
# 192            3.79             1.00%         $0.92
# 68             2.87            32.70%         $0.79
# 138            2.58            27.80%         $0.86
# 176            3.56            12.50%            NaN

# %%
#4. Muestra el nombre de todas las columnas en el conjunto de datos.
df_wordl.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
#5. Muestra los valores únicos en la columna "Abbreviation".

df_wordl["Abbreviation"].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# ** BONUS DE EXPLORACION **
# 1. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".
#
# 2. Verifica si hay valores nulos en el conjunto de datos.
#
# 3. Verifica si hay valores no nulos en el conjunto de datos.
#
# 4. Muestra información general sobre el conjunto de datos.
#
# 5. Elimina una columna específica (por ejemplo, "Armed Forces size").
#
# 6. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
#1. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".
df_wordl["Abbreviation"].value_counts()
# Out:
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: Abbreviation, Length: 188, dtype: int64

# %%
#2.Verifica si hay valores nulos en el conjunto de datos.
df_wordl.isnull().sum()
# Out:
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %%
df_wordl.isna().sum()
# Out:
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %%
#3. Verifica si hay valores no nulos en el conjunto de datos.
df_wordl.notnull().sum()
# Out:
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %%
#4. Muestra información general sobre el conjunto de datos.
df_wordl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 30.0+ KB

# %%
#5. Elimina una columna específica (por ejemplo, "Armed Forces size"). inplace=true hace que se borre permanentemente. axis = 1 indica columna , axis = 0 indica fila
df_wordl.drop("Armed Forces size", axis=1,inplace=True)

# %%
#6. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).
df_wordl.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %% [markdown]
# ** EJERCICIOS LOS E ILOC **
# 1. Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.
#
# 2. Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.
#
# 3. Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.
#
# 4. Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.
#
# 5. Encuentra el valor en la fila 2 y columna 7 utilizando iloc.
#
# 6. Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.

# %%
df_wordl
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %%
#1. Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.
df_wordl.loc[2:4,:]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#   Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 2       150,006  151.36          2.00%           DZD            3.02
# 3           469     NaN            NaN           EUR            1.27
# 4        34,693  261.73         17.10%           AOA            5.52
#
#   Forested Area (%) Gasoline Price
# 2             0.80%         $0.28
# 3            34.00%         $1.51
# 4            46.30%         $0.97

# %%
#2. Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.
df_wordl.loc[df_wordl["Birth Rate"]>30]

# %%
#3. Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.
df_wordl.loc[df_wordl["Fertility Rate"]>3, ["Country","Capital/Major City"]]

# %%
#4. Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.
df_wordl.iloc[:, 0:4]
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
# [195 rows x 4 columns]

# %%
#5. Encuentra el valor en la fila 2 y columna 7 utilizando iloc.
df_wordl.iloc[2:3,7:8]
# Out:
#    Calling Code
# 2         213.0

# %%
#6. Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.
df_wordl.iloc[:, [0,2,5]]
# Out:
#          Country Abbreviation Armed Forces size
# 0    Afghanistan           AF           323,000
# 1        Albania           AL             9,000
# 2        Algeria           DZ           317,000
# 3        Andorra           AD               NaN
# 4         Angola           AO           117,000
# ..           ...          ...               ...
# 190    Venezuela           VE           343,000
# 191      Vietnam           VN           522,000
# 192        Yemen           YE            40,000
# 193       Zambia           ZM            16,000
# 194     Zimbabwe           ZW            51,000
#
# [195 rows x 3 columns]

# %% [markdown]
# ** BONUS DE LOC Y ILOC **
#
# 1. Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.
#
# 2. Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.
#
# 3. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.
#
# 4. Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.
#
# 5. Selecciona las columnas "Country" y "Co2-Emissions".
#
# 6. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").
#
# 7. Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.
#
# 8. Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.
#
# 9. Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
df_wordl
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0          652,230       32.49          93.0              Kabul         8,672
# 1           28,748       11.78         355.0             Tirana         4,536
# 2        2,381,741       24.28         213.0            Algiers       150,006
# 3              468        7.20         376.0   Andorra la Vella           469
# 4        1,246,700       40.73         244.0             Luanda        34,693
# ..             ...         ...           ...                ...           ...
# 190        912,050       17.88          58.0            Caracas       164,175
# 191        331,210       16.75          84.0              Hanoi       192,668
# 192        527,968       30.45         967.0              Sanaa        10,609
# 193        752,618       36.19         260.0             Lusaka         5,141
# 194        390,757       30.68         263.0             Harare        10,983
#
#           CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0       149.9          2.30%           AFN            4.47             2.10%
# 1      119.05          1.40%           ALL            1.62            28.10%
# 2      151.36          2.00%           DZD            3.02             0.80%
# 3         NaN            NaN           EUR            1.27            34.00%
# 4      261.73         17.10%           AOA            5.52            46.30%
# ..        ...            ...           ...             ...               ...
# 190  2,740.27        254.90%           VED            2.27            52.70%
# 191    163.52          2.80%           VND            2.05            48.10%
# 192    157.58          8.10%           YER            3.79             1.00%
# 193    212.31          9.20%           ZMW            4.63            65.20%
# 194    105.51          0.90%           NaN            3.62            35.50%
#
#     Gasoline Price
# 0           $0.70
# 1           $1.36
# 2           $0.28
# 3           $1.51
# 4           $0.97
# ..             ...
# 190         $0.00
# 191         $0.80
# 192         $0.92
# 193         $1.40
# 194         $1.34
#
# [195 rows x 15 columns]

# %%
#1. Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.
df_wordl.loc[df_wordl["Abbreviation"] == "AL", "Gasoline Price"]
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %%
#2. Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.
df_wordl.loc[df_wordl["Capital/Major City"] == "Tirana", :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 1       11.78         355.0             Tirana         4,536  119.05
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 1         $1.36

# %%
#3. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.
df_wordl.loc[df_wordl["CPI"] == "128.85"]
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 40  Costa Rica              100           CR                34.50%
#
#    Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 40         51,100       13.97         506.0      San Jos������         8,023
#
#        CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 40  128.85          2.10%           CRC            1.75            54.60%
#
#    Gasoline Price
# 40         $0.98

# %%
#4. Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.
df_wordl.loc[df_wordl["Abbreviation"] == "AD", "Density\n(P/Km2)"]
# Out:
# 3    164
# Name: Density\n(P/Km2), dtype: object

# %%
#5. Selecciona las columnas "Country" y "Co2-Emissions".
df_wordl.loc[: ,["Country","Co2-Emissions"]]
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]
